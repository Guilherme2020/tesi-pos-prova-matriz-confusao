# %%
import pandas as pd


df = pd.read_csv('train.csv')

print(df[ df['Survived'] == 1 ])


sobreviventes = len(df[ df['Survived'] == 1 ])
total = len(df)
print('Porcentagem de sobreviventes: ', (sobreviventes/total)*100, '%')

sobreviventes_classe01 = len(df[ (df['Survived'] == 1 )& (df['Sex'] ==  "female") & (df["Pclass"]==1)])
total_classe1 = len(df[(df['Sex'] ==  "female") & (df["Pclass"]==1)])
sobreviventes_classe02 = len(df[ (df['Survived'] == 1 )& (df['Sex'] ==  "female") & (df["Pclass"]==2)])
total_classe2 = len(df[(df['Sex'] ==  "female") & (df["Pclass"]==2)])
sobreviventes_classe03 = len(df[ (df['Survived'] == 1 )& (df['Sex'] ==  "female") & (df["Pclass"]==3)])
total_classe3 = len(df[(df['Sex'] ==  "female") & (df["Pclass"]==3)])


print('Porcentagem de sobreviventes da classe 1: ', (sobreviventes_classe01/total_classe1)*100, '%')
print('Porcentagem de sobreviventes da classe 2: ', (sobreviventes_classe02/total_classe2)*100, '%')
print('Porcentagem de sobreviventes da classe 3: ', (sobreviventes_classe03/total_classe3)*100, '%')


df = df.dropna(subset=['Embarked',])
print(df[df['Embarked'].isnull()])


df['Sex'] = df['Sex'].map( {'female': 0, 'male': 1} )

df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
print(df)

df['IsAlone'] = (df['FamilySize']<=1)
df['IsAlone'] = df['IsAlone'].map( {True: 1, False: 0} )
print(df)

embarked = pd.get_dummies(df['Embarked']) 
print(embarked)

x = df[['Sex','IsAlone','Embarked', 'Pclass']]
y = df['Survived']

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier



X = pd.get_dummies(x)
x_treino, x_teste, y_treino, y_teste = \
        train_test_split(X, y, test_size = 0.20, random_state = 0 )

modelo = MultinomialNB()


modelo.fit(x_treino, y_treino)
modelo.score(x_teste, y_teste)


classificador = RandomForestClassifier(n_estimators=100,max_depth=2,random_state=0)

classsificador.fit(x_treino,y_treino)
classificador.score(x_teste,y_teste)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
import pandas as pd


df = pd.read_csv('train.csv')

print(df[ df['Survived'] == 1 ])


sobreviventes = len(df[ df['Survived'] == 1 ])
total = len(df)
print('Porcentagem de sobreviventes: ', (sobreviventes/total)*100, '%')

sobreviventes_classe01 = len(df[ (df['Survived'] == 1 )& (df['Sex'] ==  "female") & (df["Pclass"]==1)])
total_classe1 = len(df[(df['Sex'] ==  "female") & (df["Pclass"]==1)])
sobreviventes_classe02 = len(df[ (df['Survived'] == 1 )& (df['Sex'] ==  "female") & (df["Pclass"]==2)])
total_classe2 = len(df[(df['Sex'] ==  "female") & (df["Pclass"]==2)])
sobreviventes_classe03 = len(df[ (df['Survived'] == 1 )& (df['Sex'] ==  "female") & (df["Pclass"]==3)])
total_classe3 = len(df[(df['Sex'] ==  "female") & (df["Pclass"]==3)])


print('Porcentagem de sobreviventes da classe 1: ', (sobreviventes_classe01/total_classe1)*100, '%')
print('Porcentagem de sobreviventes da classe 2: ', (sobreviventes_classe02/total_classe2)*100, '%')
print('Porcentagem de sobreviventes da classe 3: ', (sobreviventes_classe03/total_classe3)*100, '%')


df = df.dropna(subset=['Embarked',])
print(df[df['Embarked'].isnull()])


df['Sex'] = df['Sex'].map( {'female': 0, 'male': 1} )

df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
print(df)

df['IsAlone'] = (df['FamilySize']<=1)
df['IsAlone'] = df['IsAlone'].map( {True: 1, False: 0} )
print(df)

embarked = pd.get_dummies(df['Embarked']) 
print(embarked)

x = df[['Sex','IsAlone','Embarked', 'Pclass']]
y = df['Survived']

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier



X = pd.get_dummies(x)
x_treino, x_teste, y_treino, y_teste = \
        train_test_split(X, y, test_size = 0.20, random_state = 0 )

modelo = MultinomialNB()


modelo.fit(x_treino, y_treino)
modelo.score(x_teste, y_teste)


classificador = RandomForestClassifier(n_estimators=100,max_depth=2,random_state=0)

classificador.fit(x_treino,y_treino)
classificador.score(x_teste,y_teste)
#
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier



X = pd.get_dummies(x)
x_treino, x_teste, y_treino, y_teste = \
        train_test_split(X, y, test_size = 0.20, random_state = 0 )

modelo = MultinomialNB()


modelo.fit(x_treino, y_treino)
modelo.score(x_teste, y_teste)


classificador = RandomForestClassifier(n_estimators=100,max_depth=2,random_state=0)

classificador.fit(x_treino,y_treino)
classificador.score(x_teste,y_teste)
# Out:
# 0.7415730337078652

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier



X = pd.get_dummies(x)
x_treino, x_teste, y_treino, y_teste = \
        train_test_split(X, y, test_size = 0.20, random_state = 0 )

modelo = MultinomialNB()


modelo.fit(x_treino, y_treino)
modelo.score(x_teste, y_teste)
# Out:
# 0.6404494382022472

# %%
classificador = RandomForestClassifier(n_estimators=100,max_depth=2,random_state=0)

classificador.fit(x_treino,y_treino)
classificador.score(x_teste,y_teste)
# Out:
# 0.7415730337078652

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix

gausiNb = GaussianNB()

gausiNb.fit(x_treino,y_treino)
gausiNb.score(x_teste,y_teste)
# Out:
# 0.702247191011236

# %%
from sklearn.tree import DecisionTreeClassifier

adaBoost =  AdaBoostClassifier(DecisionTreeClassifier(max_depth=1),
                         algorithm="SAMME",
                         n_estimators=200)

adaBoost.fit(x_treino,y_treino)
adaBoost.score(x_teste,y_teste)
# Out:
# 0.7078651685393258

# %%
print(confusion_matrix(y_teste,classificador.predict(x_teste)))
print(confusion_matrix(y_teste,gausiNb.predict(x_teste)))
print(confusion_matrix(y_teste,adaBoost.predict(x_teste)))
# Out:
# [[95 10]
#  [36 37]]
# [[79 26]
#  [27 46]]
# [[80 25]
#  [27 46]]
